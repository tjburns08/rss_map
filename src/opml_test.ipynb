# %%
import xml.etree.ElementTree as ET

def parse_opml(file_path):
    '''
    Description: Takes the file path of an OPML file and extracts the RSS feed URLs.
    Args:
        file_path: A string representing the path to the OPML file.
    Returns: A list of RSS feed URLs.
    '''
    
    # Parse the OPML file using ElementTree
    tree = ET.parse(file_path)
    root = tree.getroot()

    # Initialize an empty list to store the feed URLs
    feeds = []

    # Iterate through the 'outline' elements in the OPML file
    for elem in root.iter('outline'):
        # Extract the 'xmlUrl' attribute containing the RSS feed URL
        url = elem.get('xmlUrl')

        # If the URL exists, append it to the feeds list
        if url:
            feeds.append(url)

    # Return the list of feed URLs
    return feeds

# %%
feeds = parse_opml('../data/tyler-rss-subscriptions.opml')
feeds
# Out:
# ['http://mikudb.moe/feed/',
#  'https://frozenstarfall.net/feed/',
#  'http://bunkai-kei.com/feed/',
#  'https://kill-the-newsletter.com/feeds/cfp02mmxp2rhdpfq.xml',
#  'https://www.animenewsnetwork.com/review/rss.xml',
#  'https://www.animenewsnetwork.com/feature/rss.xml',
#  'https://www.evageeks.org/feed/',
#  'https://fullfrontal.moe/feed/',
#  'https://buttercupfestival.tumblr.com/rss',
#  'http://feeds.feedburner.com/Buttersafe',
#  'https://qwantz.com/rssfeed.php',
#  'https://www.paranatural.net/comic/rss',
#  'http://feeds.penny-arcade.com/pa-mainsite/',
#  'http://sssscomic.com/ssss-feed.xml',
#  'https://www.oglaf.com/feeds/rss/',
#  'https://www.smbc-comics.com/comic/rss',
#  'https://pbfcomics.com/feed/',
#  'http://feeds.feedburner.com/wondermark',
#  'https://xkcd.com/atom.xml',
#  'http://thesecretknots.com/feed/',
#  'http://dresdencodak.com/feed/',
#  'http://askakorean.blogspot.com/feeds/posts/default',
#  'http://populargusts.blogspot.com/feeds/posts/default',
#  'http://freekorea.us/feed/',
#  'http://www.econtalk.org/feed/',
#  'https://www.econlib.org/feed/main',
#  'http://feeds.feedburner.com/marginalrevolution/feed',
#  'http://feeds.feedburner.com/Themoneyillusion',
#  'http://unenumerated.blogspot.com/feeds/posts/default',
#  'https://www.bloomberg.com/opinion/authors/ARbTQlRLRjE/matthew-s-levine.rss',
#  'https://www.annualreviews.org/r/economics_rss',
#  'https://chrisblattman.com/feed/',
#  'https://fantasticanachronism.com/atom.xml',
#  'https://resobscura.blogspot.com/feeds/posts/default',
#  'http://ralafferty.tumblr.com/rss',
#  'http://antsofgodarequeerfish.blogspot.com/feeds/posts/default',
#  'https://www.newyorker.com/feed/everything',
#  'http://ultan.org.uk/feed/',
#  'https://kill-the-newsletter.com/feeds/m8q3pfxjfrtk8xhj.xml',
#  'http://reflectivedisequilibrium.blogspot.com/feeds/posts/default',
#  'http://aleph.se/andart2/feed/',
#  'http://www.bayesianinvestor.com/blog/index.php/feed/',
#  'https://www.lesswrong.com/feed.xml',
#  'https://www.reddit.com/domain/lesswrong.com/.rss',
#  'https://meteuphoric.com/feed/',
#  'http://www.overcomingbias.com/feed',
#  'http://feeds.feedburner.com/PhilosophyEtCetera',
#  'http://feeds.feedburner.com/Quodlibeta',
#  'https://www.reddit.com/domain/gwern.net/.rss',
#  'http://www.ashokkarra.com/feed/',
#  'https://www.richardcarrier.info/feed',
#  'https://www.scottaaronson.com/blog/?feed=rss2',
#  'https://plato.stanford.edu/rss/sep.xml',
#  'http://bactra.org/weblog/index.rss',
#  'http://leahneukirchen.org/trivium/index.atom',
#  'https://www.umsu.de/blog/rss.xml',
#  'https://slatestarcodex.com/feed/',
#  'https://slatestarscratchpad.tumblr.com/rss',
#  'https://astralcodexten.substack.com/feed/',
#  'https://qualiacomputing.com/feed/',
#  'https://www.alignmentforum.org/feed.xml',
#  'https://thezvi.wordpress.com/feed/',
#  'https://applieddivinitystudies.com/atom.xml',
#  'https://kill-the-newsletter.com/feeds/saai8csyfofi4n3z.xml',
#  'https://econstudentlog.wordpress.com/feed/',
#  'https://entitledtoanopinion.wordpress.com/feed/',
#  'http://feeds.feedburner.com/typepad/rzYD',
#  'http://www.isegoria.net/feed/',
#  'https://longform.org/feed.rss',
#  'https://accounts.google.com/ServiceLogin?service=ah&passive=true&continue=https://uc.appengine.google.com/_ah/conflogin%3Fcontinue%3Dhttps://us-central1-nyt-du-prd.cloudfunctions.net/services/xml/rss/nyt/magazine.xml',
#  'http://rajivsethi.blogspot.com/feeds/posts/default',
#  'https://www.ribbonfarm.com/feed/',
#  'http://feeds.feedburner.com/givewell/rss2',
#  'http://feeds.feedburner.com/AbandonedFootnotes',
#  'https://scholars-stage.blogspot.com/feeds/posts/default',
#  'https://publicdomainreview.org/feed/',
#  'https://dormin.org/feed/',
#  'https://feeds.feedburner.com/damninteresting/all',
#  'https://commonreader.substack.com/feed/',
#  'https://warontherocks.com/feed/',
#  'http://www.goodmath.org/blog/feed/',
#  'https://rjlipton.wpcomstaging.com/feed/',
#  'https://blogs.sciencemag.org/pipeline/feed',
#  'https://www.fightaging.org/feed/',
#  'https://rss.nytimes.com/services/xml/rss/nyt/Science.xml',
#  'https://what-if.xkcd.com/feed.atom',
#  'https://blog.xkcd.com/feed/',
#  'https://pnis.co/feed/',
#  'https://api.obormot.net/rss/NationalAffairsDailyFindingsFeed.php',
#  'https://www.atlasobscura.com/feeds/latest',
#  'https://www.annualreviews.org/r/soc_rss',
#  'https://www.annualreviews.org/r/psych_rss',
#  'https://www.annualreviews.org/r/clinpsy_rss',
#  'https://api.quantamagazine.org/feed/',
#  'https://bestoftwitter.substack.com/feed/',
#  'https://kill-the-newsletter.com/feeds/s0xwmajqfzdcw4ys.xml',
#  'https://kill-the-newsletter.com/feeds/qq3ts9fz9762hzu9.xml',
#  'https://pubmed.ncbi.nlm.nih.gov/rss/search/1LK5GZMdRGzFtio1iyKtCeglrU29X1jeNV4mBaejbUAJOeXw7m/?limit=100&utm_campaign=pubmed-2&fc=20210328125500',
#  'https://pubmed.ncbi.nlm.nih.gov/rss/search/1dcEXTzh6xe1f9p9XuMEF2noqb_WxlQz337gUbCUO4TWJcGQme/?limit=100&utm_campaign=pubmed-2&fc=20210328125803',
#  'https://pubmed.ncbi.nlm.nih.gov/rss/search/1dwOEnJFpGXo0QFwLCKG-Z0yeq0wkMnzd5wM1mo1wWDy80Mk7J/?limit=100&utm_campaign=pubmed-2&fc=20210401094757',
#  'https://pubmed.ncbi.nlm.nih.gov/rss/search/1Re_a8-P-JvsuqmS-9fvZjk6_uemMINUHwlK3XtW_eCobmkUyt/?limit=100&utm_campaign=pubmed-2&fc=20210328130118',
#  'http://datacolada.org/feed',
#  'https://statmodeling.stat.columbia.edu/feed/',
#  'https://tdhopper.com/blog/?format=rss',
#  'https://www.johndcook.com/blog/feed/',
#  'https://thehardestscience.com/feed/',
#  'http://feeds.pinboard.in/rss/u:cshalizi/',
#  'https://www.straighttalkonevidence.org/feed/',
#  'https://feeds.feedburner.com/80000HoursPodcast',
#  'https://www.annualreviews.org/r/statistics_rss',
#  'http://feeds.feedburner.com/blogspot/gJZg',
#  'https://karpathy.github.io/feed.xml',
#  'https://colah.github.io/rss.xml',
#  'http://feeds.feedburner.com/miriblog',
#  'https://timdettmers.com/feed/',
#  'https://bair.berkeley.edu/blog/feed.xml',
#  'https://jack-clark.net/feed/',
#  'https://www.alexirpan.com/feed.xml',
#  'https://aiimpacts.org/feed/',
#  'https://chinai.substack.com/feed/',
#  'http://newsletter.ruder.io/?format=rss',
#  'https://us15.campaign-archive.com/feed?u=c7e080421931e2a646364e3ef&id=a23c388b9d',
#  'https://infoproc.blogspot.com/feeds/posts/default',
#  'https://connect.biorxiv.org/biorxiv_xml.php?subject=all',
#  'http://connect.medrxiv.org/medrxiv_xml.php?subject=Genetic_and_Genomic_Medicine',
#  'http://connect.medrxiv.org/medrxiv_xml.php?subject=Psychiatry_and_Clinical_Psychology',
#  'http://connect.medrxiv.org/medrxiv_xml.php?subject=Health_Economics',
#  'http://connect.medrxiv.org/medrxiv_xml.php?subject=Epidemiology',
#  'https://feeds.feedburner.com/RazibKhansTotalFeed',
#  'https://www.annualreviews.org/r/biodatasci_rss',
#  'https://www.annualreviews.org/r/genom_rss',
#  'https://www.annualreviews.org/r/genet_rss',
#  'https://www.annualreviews.org/action/showFeed?ui=45mu4&mi=3fndc3&ai=sh&jc=ecolsys&type=etoc&feed=atom',
#  'https://krebsonsecurity.com/feed/',
#  'http://grugq.tumblr.com/rss',
#  'http://funcall.blogspot.com/feeds/posts/default',
#  'https://apenwarr.ca/log/rss.php',
#  'http://ascii.textfiles.com/feed/atom',
#  'http://feeds.feedburner.com/Betterexplained',
#  'https://bitslog.com/feed/',
#  'https://ideas.4brad.com/index.rdf',
#  'http://www.antipope.org/charlie/blog-static/atom.xml',
#  'http://feeds.feedburner.com/codahale',
#  'http://feeds.feedburner.com/daniel-lemire/atom',
#  'http://eli.thegreenplace.net/feed/',
#  'https://blog.regehr.org/feed',
#  'https://financialcryptography.com/index.rdf',
#  'http://glinden.blogspot.com/feeds/posts/default',
#  'https://geoff.greer.fm/feed.atom',
#  'http://lambda-the-ultimate.org/rss.xml',
#  'http://math.andrej.com/feed.xml',
#  'https://www.kalzumeus.com/feed/articles/',
#  'https://blog.nearlyfreespeech.net/feed/',
#  'https://www.rifters.com/crawl/?feed=rss2',
#  'http://www.aaronsw.com/2002/feeds/pgessays.rss',
#  'https://www.schneier.com/blog/atom.xml',
#  'https://blog.longnow.org/feed/',
#  'http://feeds.feedburner.com/QuantifiedSelf',
#  'https://qntm.org/rss.php',
#  'https://www.wired.com/feed/',
#  'https://www.filfre.net/feed/',
#  'https://kill-the-newsletter.com/feeds/t0mfv8eb5q8vbjdp.xml',
#  'https://blog.bolt.io/feed/',
#  'https://danluu.com/atom.xml',
#  'https://blog.acolyer.org/feed/',
#  'https://danwang.co/feed/',
#  'https://antonhowes.substack.com/feed/',
#  'https://technicshistory.com/feed/',
#  'https://feed.tedium.co/',
#  'https://www.debian.org/News/weekly/dwn.en.rdf',
#  'https://a16z.com/feed/',
#  'http://tib.matthewclifford.com/?format=rss',
#  'https://kill-the-newsletter.com/feeds/t783q6gy0aylc88a.xml',
#  'https://www.eugenewei.com/blog?format=rss',
#  'https://www.bldgblog.com/feed/',
#  'https://www.robinsloan.com/feed/index.xml',
#  'https://ilovetypography.com/feed/',
#  'https://typesetinthefuture.com/feed/',
#  'https://typography.guru/weekly/?rss=1',
#  'https://stackoverflow.blog/feed/',
#  'https://rethinkdisruption.com/feed/',
#  'https://wiki.lesswrong.com/api.php?hidebots=1&days=7&limit=50&hidelogs=1&action=feedrecentchanges&feedformat=atom',
#  "https://www.reddit.com/r/gwern/search.rss?q=flair:'Gwern'&sort=new&restrict_sr=on",
#  'http://www.tlmc.eu/feeds/posts/default']

# %%
import feedparser
import pandas as pd

# Make a function out of this
def rss_to_df(feed, source):
    '''
    Description: Takes a feedparser object and converts it to a Pandas DataFrame
    Args:
        feed: A feedparser object
    Returns: A Pandas DataFrame
    '''
    #df = pd.DataFrame({'title': feed.entries[0].title, 'link': feed.entries[0].link, 'published': feed.entries[0].published}, index=[0])
    df = pd.DataFrame()
    for i in range(len(feed.entries)):
        entry = feed.entries[i]
        curr = pd.DataFrame({'title': entry.title, 'link': entry.link, 'summary': entry.summary, 'published': entry.published}, index=[i])
        df = pd.concat([df, curr], ignore_index=True)
    df['source'] = source

    # Convert the published column to a datetime object
    df['published'] = pd.to_datetime(df['published'])

    # Fix the "- AP news - en español" at the end of the title
    df['title'] = df['title'].str.replace(' - The Associated Press - en Español', '')
    return df

# Iterate over the feeds and process them
feed = feedparser.parse(feeds[0])
feed.entries[0].author
# Out:
# 'Kyrozen'

# %%
df = pd.DataFrame()
for feed_url in feeds[1:5]:
    try:
        feed = feedparser.parse(feed_url)
        out = rss_to_df(feed, "")
        df = pd.concat([df, out], ignore_index=True)
    except Exception as e:
        print(f"Error processing feed URL: {feed_url}. Error: {e}")
# Out:
# Error processing feed URL: https://kill-the-newsletter.com/feeds/cfp02mmxp2rhdpfq.xml. Error: object has no attribute 'published'

# %%
df
# Out:
#                                                 title  \
# 0                             Comiket 99 announcement
# 1                 LUNARTANZ (2021 Ver.) & Nhato Remix
# 2                                              Hiatus
# 3                         New works for Air Comiket 2
# 4                            Comiket 97 announcements
# 5                                              Kotoba
# 6                                               Leave
# 7                                               Lucoq
# 8                                             Dragoon
# 9                                        dendel voile
# 10                                 Create A New World
# 11                                            Lycoris
# 12                                             Emboss
# 13                                         Polyphenic
# 14                                              films
# 15               The Villainess Stans the Heroes GN 1
# 16                         Arknights: Prelude to Dawn
# 17                      My Clueless First Friend GN 1
# 18                                           Downfall
# 19                                         Helck GN 2
# 20                   Monster Episodes 31-52 Streaming
# 21  The Disowned Queen's Consulting Detective Agen...
# 40  Ragna Crimson Volume 7 is basically like liste...
# 41  I Want to Be a Wall is a needed piece of repre...
# 42  This striking volume from the creator of Tokyo...
# 43  What SCRAMBLUES lacks in romance, it makes up ...
# 44  A lot is going on here, from the quiet pain of...
# 45  The newest novel Tatami Galaxy's  Tomihiko Mor...
# 46  You cannot help but fall into the rhythm of da...
# 47  Make My Day is a derivative work lacking any i...
# 48  Convenient Princess is effectively a case of t...
# 49  Wild Hearts <i>feels</i> like a variant of <ci...
# 50  I was lukewarm about the first volume of Tokyo...
# 51  This autobiographical manga recounts "an otaku...
# 52  All in all, Record of Ragnarok Season 2 is bet...
# 53  Along with being one of the most consumable li...
# 54  Barbarities' first volume is an interesting op...
#
#                     published source
# 0   2021-12-12 19:28:03+00:00
# 1   2021-09-24 09:35:20+00:00
# 2   2021-04-04 16:49:22+00:00
# 3   2020-12-14 18:59:08+00:00
# 4   2019-12-18 16:59:12+00:00
# 5   2017-04-27 13:58:20+00:00
# 6   2015-12-10 14:00:03+00:00
# 7   2015-03-19 13:30:55+00:00
# 8   2015-02-26 13:58:06+00:00
# 9   2014-12-18 13:58:26+00:00
# 10  2014-10-21 14:00:50+00:00
# 11  2014-10-09 14:00:17+00:00
# 12  2014-09-25 13:58:05+00:00
# 13  2014-09-18 13:58:56+00:00
# 14  2014-09-09 13:58:19+00:00
# 15  2023-03-20 12:00:00-04:00
# 16  2023-03-19 12:00:00-04:00
# 17  2023-03-18 12:00:00-04:00
# 18  2023-03-17 12:00:00-04:00
# 19  2023-03-16 12:00:00-04:00
# 20  2023-03-15 12:00:00-04:00
# 21  2023-03-14 12:00:00-04:00
# 22  2023-03-13 12:00:00-04:00
# 23  2023-03-12 12:00:00-04:00
# 24  2023-03-11 12:00:00-05:00
# 25  2023-03-10 12:00:00-05:00
# 26  2023-03-09 12:00:00-05:00
# 27  2023-03-08 10:00:00-05:00
# 28  2023-03-08 08:00:00-05:00
# 29  2023-03-07 12:00:00-05:00
# 30  2023-03-06 12:00:00-05:00
# 31  2023-03-05 12:00:00-05:00
# 32  2023-03-04 12:00:00-05:00
# 33  2023-03-03 09:00:00-05:00
# 34  2023-03-02 17:48:43-05:00
# 35  2023-03-02 12:00:00-05:00
# 36  2023-03-01 12:00:00-05:00
# 37  2023-02-28 12:00:00-05:00
# 38  2023-02-27 12:00:00-05:00
# 39  2023-02-25 12:00:00-05:00
# 40  2023-02-24 12:00:00-05:00
# 41  2023-02-23 12:00:00-05:00
# 42  2023-02-22 12:00:00-05:00
# 43  2023-02-21 12:00:00-05:00
# 44  2023-02-20 12:00:00-05:00
# 45  2023-02-18 12:00:00-05:00
# 46  2023-02-17 12:30:41-05:00
# 47  2023-02-17 12:00:00-05:00
# 48  2023-02-16 12:00:00-05:00
# 49  2023-02-16 10:00:00-05:00
# 50  2023-02-15 12:00:00-05:00
# 51  2023-02-14 12:00:00-05:00
# 52  2023-02-13 12:00:00-05:00
# 53  2023-02-12 12:00:00-05:00
# 54  2023-02-11 12:00:00-05:00

# %%
import feedparser
import xml.etree.ElementTree as ET
import pandas as pd

def parse_opml(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    feeds = []
    for elem in root.iter('outline'):
        url = elem.get('xmlUrl')
        if url:
            feeds.append(url)
    return feeds

def rss_reader(feed_url):
    feed = feedparser.parse(feed_url)
    feed_entries = []

    for entry in feed.entries:
        feed_entries.append({
            'feed_title': feed.feed.title,
            'title': entry.title,
            'summary': entry.summary,
            'link': entry.link,
            'published': entry.published
        })

    return feed_entries

if __name__ == "__main__":
    opml_file = "../data/tyler-rss-subscriptions.opml"
    output_csv = "../output/opml_output.csv"
    
    feeds = parse_opml(opml_file)

    all_feed_entries = []

    for feed_url in feeds:
        try:
            all_feed_entries.extend(rss_reader(feed_url))
        except Exception as e:
            print(f"Error processing feed URL: {feed_url}. Error: {e}")

    df = pd.DataFrame(all_feed_entries)
    df.to_csv(output_csv, index=False)
# Out:
# Error processing feed URL: https://kill-the-newsletter.com/feeds/cfp02mmxp2rhdpfq.xml. Error: object has no attribute 'published'
# Error processing feed URL: http://sssscomic.com/ssss-feed.xml. Error: object has no attribute 'published'
# Error processing feed URL: https://xkcd.com/atom.xml. Error: object has no attribute 'published'
# Error processing feed URL: https://kill-the-newsletter.com/feeds/m8q3pfxjfrtk8xhj.xml. Error: object has no attribute 'published'
# Error processing feed URL: http://bactra.org/weblog/index.rss. Error: object has no attribute 'published'
# Error processing feed URL: https://slatestarscratchpad.tumblr.com/rss. Error: object has no attribute 'summary'
# Error processing feed URL: https://kill-the-newsletter.com/feeds/saai8csyfofi4n3z.xml. Error: object has no attribute 'published'
# Error processing feed URL: https://kill-the-newsletter.com/feeds/s0xwmajqfzdcw4ys.xml. Error: object has no attribute 'published'
# Error processing feed URL: https://kill-the-newsletter.com/feeds/qq3ts9fz9762hzu9.xml. Error: object has no attribute 'published'
# Error processing feed URL: http://feeds.pinboard.in/rss/u:cshalizi/. Error: object has no attribute 'published'
# Error processing feed URL: https://feeds.feedburner.com/80000HoursPodcast. Error: object has no attribute 'link'
# Error processing feed URL: https://connect.biorxiv.org/biorxiv_xml.php?subject=all. Error: object has no attribute 'published'
# Error processing feed URL: http://connect.medrxiv.org/medrxiv_xml.php?subject=Genetic_and_Genomic_Medicine. Error: object has no attribute 'published'
# Error processing feed URL: http://connect.medrxiv.org/medrxiv_xml.php?subject=Psychiatry_and_Clinical_Psychology. Error: object has no attribute 'published'
# Error processing feed URL: http://connect.medrxiv.org/medrxiv_xml.php?subject=Health_Economics. Error: object has no attribute 'published'
# Error processing feed URL: http://connect.medrxiv.org/medrxiv_xml.php?subject=Epidemiology. Error: object has no attribute 'published'
# Error processing feed URL: http://grugq.tumblr.com/rss. Error: object has no attribute 'title'
# Error processing feed URL: https://financialcryptography.com/index.rdf. Error: object has no attribute 'published'
# Error processing feed URL: https://geoff.greer.fm/feed.atom. Error: object has no attribute 'published'
# Error processing feed URL: http://www.aaronsw.com/2002/feeds/pgessays.rss. Error: object has no attribute 'summary'
# Error processing feed URL: https://kill-the-newsletter.com/feeds/t0mfv8eb5q8vbjdp.xml. Error: object has no attribute 'published'
# Error processing feed URL: https://www.debian.org/News/weekly/dwn.en.rdf. Error: object has no attribute 'published'
# Error processing feed URL: https://kill-the-newsletter.com/feeds/t783q6gy0aylc88a.xml. Error: object has no attribute 'published'
